# %%
# %openad oad_prop generate with TorchDrugGraphAF data  sample 10 using ( algorithm_version=zinc250k_v0 )
# Out:
# <span style="color: #d00">Not a valid command</span> <br>
# <span style="color: #ccc">generate with TorchDrugGraphAF data sample 10 using ( algorithm_version=zinc250k_v0 ) <br>
#    ^</span> <br>
# <span style="color: #dc0">Commands starting with "gen"</span> <br>
# - `gen generate with AaeGenerator data  for  <object> (sample <sample_size>) USING (<parameter>=<value> <parameter>=<value>)  (save_as '<filename.csv>')` <br>
# - `gen generate with CatalystGenerator data  for  <number> (sample <sample_size>) USING (<parameter>=<value> <parameter>=<value>)  (save_as '<filename.csv>')` <br>
# - `gen generate with GraphGAGenerator data  for  <object> (sample <sample_size>) USING (<parameter>=<value> <parameter>=<value>)  (save_as '<filename.csv>')` <br>
# - `gen generate with GraphMCTSGenerator data  for  <object> (sample <sample_size>) USING (<parameter>=<value> <parameter>=<value>)  (save_as '<filename.csv>')` <br>
# ...

# %%
# %openad model service status
# Out:
# Output()
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_50f59">
#   <thead>
#     <tr>
#       <th id="T_50f59_level0_col0" class="col_heading level0 col0" >Service</th>
#       <th id="T_50f59_level0_col1" class="col_heading level0 col1" >Status</th>
#       <th id="T_50f59_level0_col2" class="col_heading level0 col2" >Endpoint</th>
#       <th id="T_50f59_level0_col3" class="col_heading level0 col3" >Host</th>
#       <th id="T_50f59_level0_col4" class="col_heading level0 col4" >API expires</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_50f59_row0_col0" class="data row0 col0" >property_model</td>
#       <td id="T_50f59_row0_col1" class="data row0 col1" >Unreachable</td>
#       <td id="T_50f59_row0_col2" class="data row0 col2" >http://localhost:8080</td>
# ...

# %%
# %openad model service down oad_prop
# Out:
# Output()
