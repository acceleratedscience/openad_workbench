# %% [markdown]
# ### Substituting Data & merging into molecule working sets

# %%
# setup properties and molecules you wish to work with
properties_all = ['molecular_weight', 'number_of_aromatic_rings', 'number_of_h_acceptors', 'number_of_atoms','number_of_rings', 'number_of_rotatable_bonds', 'number_of_large_rings', 'number_of_heterocycles', 'number_of_stereocenters','is_scaffold', 'bertz', 'tpsa', 'logp', 'qed', 'plogp', 'penalized_logp', 'lipinski', 'sas', 'esol']
a_molecule_list = [ 'O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F', 'ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F', 'C(C(C1C(=C(C(=O)O1)O)O)O)O' ]

# %% [markdown]
# run property generation and merge molecules into the molecules working set which is a set of molecules we manage in memory for you

# %%
# %openad prop get molecule property {properties_all} for  {a_molecule_list} merge with mols
# Out:
# Output()
# <span style="color: #090">Molecule Data Merged</span> <br>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_62140">
#   <thead>
#     <tr>
#       <th id="T_62140_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_62140_level0_col1" class="col_heading level0 col1" >property</th>
#       <th id="T_62140_level0_col2" class="col_heading level0 col2" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62140_row0_col0" class="data row0 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row0_col1" class="data row0 col1" >molecular_weight</td>
#       <td id="T_62140_row0_col2" class="data row0 col2" >328.058000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row1_col0" class="data row1 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row1_col1" class="data row1 col1" >molecular_weight</td>
#       <td id="T_62140_row1_col2" class="data row1 col2" >333.053000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row2_col0" class="data row2 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row2_col1" class="data row2 col1" >molecular_weight</td>
#       <td id="T_62140_row2_col2" class="data row2 col2" >176.124000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row3_col0" class="data row3 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row3_col1" class="data row3 col1" >number_of_aromatic_rings</td>
#       <td id="T_62140_row3_col2" class="data row3 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row4_col0" class="data row4 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row4_col1" class="data row4 col1" >number_of_aromatic_rings</td>
#       <td id="T_62140_row4_col2" class="data row4 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row5_col0" class="data row5 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row5_col1" class="data row5 col1" >number_of_aromatic_rings</td>
#       <td id="T_62140_row5_col2" class="data row5 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row6_col0" class="data row6 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row6_col1" class="data row6 col1" >number_of_h_acceptors</td>
#       <td id="T_62140_row6_col2" class="data row6 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row7_col0" class="data row7 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row7_col1" class="data row7 col1" >number_of_h_acceptors</td>
#       <td id="T_62140_row7_col2" class="data row7 col2" >4.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row8_col0" class="data row8 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row8_col1" class="data row8 col1" >number_of_h_acceptors</td>
#       <td id="T_62140_row8_col2" class="data row8 col2" >6.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row9_col0" class="data row9 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row9_col1" class="data row9 col1" >number_of_atoms</td>
#       <td id="T_62140_row9_col2" class="data row9 col2" >22.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row10_col0" class="data row10 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row10_col1" class="data row10 col1" >number_of_atoms</td>
#       <td id="T_62140_row10_col2" class="data row10 col2" >22.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row11_col0" class="data row11 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row11_col1" class="data row11 col1" >number_of_atoms</td>
#       <td id="T_62140_row11_col2" class="data row11 col2" >20.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row12_col0" class="data row12 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row12_col1" class="data row12 col1" >number_of_rings</td>
#       <td id="T_62140_row12_col2" class="data row12 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row13_col0" class="data row13 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row13_col1" class="data row13 col1" >number_of_rings</td>
#       <td id="T_62140_row13_col2" class="data row13 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row14_col0" class="data row14 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row14_col1" class="data row14 col1" >number_of_rings</td>
#       <td id="T_62140_row14_col2" class="data row14 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row15_col0" class="data row15 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row15_col1" class="data row15 col1" >number_of_rotatable_bonds</td>
#       <td id="T_62140_row15_col2" class="data row15 col2" >4.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row16_col0" class="data row16 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row16_col1" class="data row16 col1" >number_of_rotatable_bonds</td>
#       <td id="T_62140_row16_col2" class="data row16 col2" >4.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row17_col0" class="data row17 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row17_col1" class="data row17 col1" >number_of_rotatable_bonds</td>
#       <td id="T_62140_row17_col2" class="data row17 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row18_col0" class="data row18 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row18_col1" class="data row18 col1" >number_of_large_rings</td>
#       <td id="T_62140_row18_col2" class="data row18 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row19_col0" class="data row19 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row19_col1" class="data row19 col1" >number_of_large_rings</td>
#       <td id="T_62140_row19_col2" class="data row19 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row20_col0" class="data row20 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row20_col1" class="data row20 col1" >number_of_large_rings</td>
#       <td id="T_62140_row20_col2" class="data row20 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row21_col0" class="data row21 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row21_col1" class="data row21 col1" >number_of_heterocycles</td>
#       <td id="T_62140_row21_col2" class="data row21 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row22_col0" class="data row22 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row22_col1" class="data row22 col1" >number_of_heterocycles</td>
#       <td id="T_62140_row22_col2" class="data row22 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row23_col0" class="data row23 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row23_col1" class="data row23 col1" >number_of_heterocycles</td>
#       <td id="T_62140_row23_col2" class="data row23 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row24_col0" class="data row24 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row24_col1" class="data row24 col1" >number_of_stereocenters</td>
#       <td id="T_62140_row24_col2" class="data row24 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row25_col0" class="data row25 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row25_col1" class="data row25 col1" >number_of_stereocenters</td>
#       <td id="T_62140_row25_col2" class="data row25 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row26_col0" class="data row26 col0" >C(C(C1C(=C(C(=O)O1)O)O)O)O</td>
#       <td id="T_62140_row26_col1" class="data row26 col1" >number_of_stereocenters</td>
#       <td id="T_62140_row26_col2" class="data row26 col2" >2.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62140_row27_col0" class="data row27 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_62140_row27_col1" class="data ro

# %% [markdown]
# ### Using @MOLS substitution of in memory working sets

# %% [markdown]
# We can aso substitute with the molecuels we just merged as well as any other molecules we choose to add to the list from pubchem

# %%
# %openad add molecule CCO force
# %openad prop get molecule property lipinski for  @mols merge with mols
# Out:
# <span style="color: #d00">Molecule already in list: CCO</span> <br>
# Output()
# <span style="color: #090">Molecule Data Merged</span> <br>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_3f498">
#   <thead>
#     <tr>
#       <th id="T_3f498_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_3f498_level0_col1" class="col_heading level0 col1" >property</th>
#       <th id="T_3f498_level0_col2" class="col_heading level0 col2" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3f498_row0_col0" class="data row0 col0" >O=C1OC(C(O)CO)C(O)=C1O</td>
#       <td id="T_3f498_row0_col1" class="data row0 col1" >lipinski</td>
#       <td id="T_3f498_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row1_col0" class="data row1 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_3f498_row1_col1" class="data row1 col1" >lipinski</td>
#       <td id="T_3f498_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row2_col0" class="data row2 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_3f498_row2_col1" class="data row2 col1" >lipinski</td>
#       <td id="T_3f498_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row3_col0" class="data row3 col0" >CCOC(=O)C(CCC1=CC=CC=C1)NC(C)C(=O)N2C3CCCC3CC2C(=O)O</td>
#       <td id="T_3f498_row3_col1" class="data row3 col1" >lipinski</td>
#       <td id="T_3f498_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row4_col0" class="data row4 col0" >CC(=O)OC1=CC=CC=C1C(=O)O</td>
#       <td id="T_3f498_row4_col1" class="data row4 col1" >lipinski</td>
#       <td id="T_3f498_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row5_col0" class="data row5 col0" >CC(C)CC1=CC=C(C=C1)C(C)C(=O)O</td>
#       <td id="T_3f498_row5_col1" class="data row5 col1" >lipinski</td>
#       <td id="T_3f498_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row6_col0" class="data row6 col0" >FC(F)(F)F.FCC(F)(F)F.FCF.FCF.FCF.FCF.FOCC(F)(F)F.FOCC(F)(F)F.O=C(F)[N-]S(=O)(=O)CF.[K+]</td>
#       <td id="T_3f498_row6_col1" class="data row6 col1" >lipinski</td>
#       <td id="T_3f498_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_3f498_row7_col0" class="data row7 col0" >CCO</td>
#       <td id="T_3f498_row7_col1" class="data row7 col1" >lipinski</td>
#       <td id="T_3f498_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %openad show molecules
# Out:
#             <style>
#                 #btn-wrap-1728011610 { height:12px; right:20px; display:flex; flex-direction:row-reverse; position:relative }
#                 #btn-wrap-1728011610 a { color:#393939; width:24px; height:24px; padding:4px; box-sizing:border-box; background:white }
#                 #btn-wrap-1728011610 a:hover { color: #0f62fe }
#             </style>
#             <div id="btn-wrap-1728011610"><a target="_blank" href="http://127.0.0.1:8024/my-mols"><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M13 14H3C2.73489 13.9996 2.48075 13.8942 2.29329 13.7067C2.10583 13.5193 2.00036 13.2651 2 13V3C2.00036 2.73489 2.10583 2.48075 2.29329 2.29329C2.48075 2.10583 2.73489 2.00036 3 2H8V3H3V13H13V8H14V13C13.9996 13.2651 13.8942 13.5193 13.7067 13.7067C13.5193 13.8942 13.2651 13.9996 13 14Z" fill="currentColor"/><path d="M10 1V2H13.293L9 6.293L9.707 7L14 2.707V6H15V1H10Z" fill="currentColor"/></svg></a><a href="#" onclick="event.preventDefault(); document.querySelector('#btn-wrap-1728011610 + iframe').src=document.querySelector('#btn-wrap-1728011610 + iframe').src;"><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M9 14C10.1867 14 11.3467 13.6481 12.3334 12.9888C13.3201 12.3295 14.0892 11.3925 14.5433 10.2961C14.9974 9.19975 15.1162 7.99335 14.8847 6.82946C14.6532 5.66558 14.0818 4.59648 13.2426 3.75736C12.4035 2.91825 11.3344 2.3468 10.1705 2.11529C9.00666 1.88378 7.80026 2.0026 6.7039 2.45673C5.60754 2.91085 4.67047 3.67989 4.01118 4.66658C3.35189 5.65328 3 6.81331 3 8V11.1L1.2 9.3L0.5 10L3.5 13L6.5 10L5.8 9.3L4 11.1V8C4 7.0111 4.29324 6.0444 4.84265 5.22215C5.39206 4.39991 6.17295 3.75904 7.08658 3.38061C8.00021 3.00217 9.00555 2.90315 9.97545 3.09608C10.9454 3.289 11.8363 3.76521 12.5355 4.46447C13.2348 5.16373 13.711 6.05465 13.9039 7.02455C14.0969 7.99446 13.9978 8.99979 13.6194 9.91342C13.241 10.8271 12.6001 11.6079 11.7779 12.1574C10.9556 12.7068 9.98891 13 9 13V14Z" fill="currentColor"/></svg></a></div><iframe src="http://127.0.0.1:8024/headless/my-mols" crossorigin="anonymous" width="100%" height="700" style="border:solid 1px #ddd;box-sizing:border-box;width:calc(100% + 20px)"></iframe>

# %% [markdown]
# ### Add more molecules by name from Pubchem

# %%
# %openad add molecule tritace
# Out:
# <span style="color: #d00">Molecule already in list: CCOC(=O)C(CCC1=CC=CC=C1)NC(C)C(=O)N2C3CCCC3CC2C(=O)O</span> <br>

# %%
# %openad add molecule aspirin force
# %openad add molecule ibuprofen force
# Out:
# <span style="color: #d00">Molecule already in list: CC(=O)OC1=CC=CC=C1C(=O)O</span> <br>
# <span style="color: #d00">Molecule already in list: CC(C)CC1=CC=C(C=C1)C(C)C(=O)O</span> <br>

# %%
# %openad add molecule C(C(F)(F)F)OF.C(C(F)(F)F)OF.C(C(F)(F)F)F.C(F)F.C(F)F.C(F)F.C(F)F.C(F)S(=O)(=O)[N-]C(=O)F.C(F)(F)(F)F.[K+] force
# Out:
# <span style="color: #d00">Molecule already in list: FC(F)(F)F.FCC(F)(F)F.FCF.FCF.FCF.FCF.FOCC(F)(F)F.FOCC(F)(F)F.O=C(F)[N-]S(=O)(=O)CF.[K+]</span> <br>

# %%
# %openad show molecules
# Out:
#             <style>
#                 #btn-wrap-1728011622 { height:12px; right:20px; display:flex; flex-direction:row-reverse; position:relative }
#                 #btn-wrap-1728011622 a { color:#393939; width:24px; height:24px; padding:4px; box-sizing:border-box; background:white }
#                 #btn-wrap-1728011622 a:hover { color: #0f62fe }
#             </style>
#             <div id="btn-wrap-1728011622"><a target="_blank" href="http://127.0.0.1:8024/my-mols"><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M13 14H3C2.73489 13.9996 2.48075 13.8942 2.29329 13.7067C2.10583 13.5193 2.00036 13.2651 2 13V3C2.00036 2.73489 2.10583 2.48075 2.29329 2.29329C2.48075 2.10583 2.73489 2.00036 3 2H8V3H3V13H13V8H14V13C13.9996 13.2651 13.8942 13.5193 13.7067 13.7067C13.5193 13.8942 13.2651 13.9996 13 14Z" fill="currentColor"/><path d="M10 1V2H13.293L9 6.293L9.707 7L14 2.707V6H15V1H10Z" fill="currentColor"/></svg></a><a href="#" onclick="event.preventDefault(); document.querySelector('#btn-wrap-1728011622 + iframe').src=document.querySelector('#btn-wrap-1728011622 + iframe').src;"><svg width="16" height="16" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M9 14C10.1867 14 11.3467 13.6481 12.3334 12.9888C13.3201 12.3295 14.0892 11.3925 14.5433 10.2961C14.9974 9.19975 15.1162 7.99335 14.8847 6.82946C14.6532 5.66558 14.0818 4.59648 13.2426 3.75736C12.4035 2.91825 11.3344 2.3468 10.1705 2.11529C9.00666 1.88378 7.80026 2.0026 6.7039 2.45673C5.60754 2.91085 4.67047 3.67989 4.01118 4.66658C3.35189 5.65328 3 6.81331 3 8V11.1L1.2 9.3L0.5 10L3.5 13L6.5 10L5.8 9.3L4 11.1V8C4 7.0111 4.29324 6.0444 4.84265 5.22215C5.39206 4.39991 6.17295 3.75904 7.08658 3.38061C8.00021 3.00217 9.00555 2.90315 9.97545 3.09608C10.9454 3.289 11.8363 3.76521 12.5355 4.46447C13.2348 5.16373 13.711 6.05465 13.9039 7.02455C14.0969 7.99446 13.9978 8.99979 13.6194 9.91342C13.241 10.8271 12.6001 11.6079 11.7779 12.1574C10.9556 12.7068 9.98891 13 9 13V14Z" fill="currentColor"/></svg></a></div><iframe src="http://127.0.0.1:8024/headless/my-mols" crossorigin="anonymous" width="100%" height="700" style="border:solid 1px #ddd;box-sizing:border-box;width:calc(100% + 20px)"></iframe>

# %% [markdown]
# ### Substitute Molecules in working set into a standard property generation

# %%
# %openad prop get molecule property lipinski for @mols
# Out:
# Output()
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`as dataframe`/`save [as '<filename.csv>']` <br>
# <style type="text/css">
# </style>
# <table id="T_f3099">
#   <thead>
#     <tr>
#       <th id="T_f3099_level0_col0" class="col_heading level0 col0" >subject</th>
#       <th id="T_f3099_level0_col1" class="col_heading level0 col1" >property</th>
#       <th id="T_f3099_level0_col2" class="col_heading level0 col2" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f3099_row0_col0" class="data row0 col0" >O=C1OC(C(O)CO)C(O)=C1O</td>
#       <td id="T_f3099_row0_col1" class="data row0 col1" >lipinski</td>
#       <td id="T_f3099_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row1_col0" class="data row1 col0" >O=C(O)C(F)(OC(O)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_f3099_row1_col1" class="data row1 col1" >lipinski</td>
#       <td id="T_f3099_row1_col2" class="data row1 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row2_col0" class="data row2 col0" >ON(O)C(F)(OC(F)(F)C(F)(F)C(F)(F)F)C(F)(F)F</td>
#       <td id="T_f3099_row2_col1" class="data row2 col1" >lipinski</td>
#       <td id="T_f3099_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row3_col0" class="data row3 col0" >CCOC(=O)C(CCC1=CC=CC=C1)NC(C)C(=O)N2C3CCCC3CC2C(=O)O</td>
#       <td id="T_f3099_row3_col1" class="data row3 col1" >lipinski</td>
#       <td id="T_f3099_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row4_col0" class="data row4 col0" >CC(=O)OC1=CC=CC=C1C(=O)O</td>
#       <td id="T_f3099_row4_col1" class="data row4 col1" >lipinski</td>
#       <td id="T_f3099_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row5_col0" class="data row5 col0" >CC(C)CC1=CC=C(C=C1)C(C)C(=O)O</td>
#       <td id="T_f3099_row5_col1" class="data row5 col1" >lipinski</td>
#       <td id="T_f3099_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row6_col0" class="data row6 col0" >FC(F)(F)F.FCC(F)(F)F.FCF.FCF.FCF.FCF.FOCC(F)(F)F.FOCC(F)(F)F.O=C(F)[N-]S(=O)(=O)CF.[K+]</td>
#       <td id="T_f3099_row6_col1" class="data row6 col1" >lipinski</td>
#       <td id="T_f3099_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <td id="T_f3099_row7_col0" class="data row7 col0" >CCO</td>
#       <td id="T_f3099_row7_col1" class="data row7 col1" >lipinski</td>
#       <td id="T_f3099_row7_col2" class="data row7 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Working with Result sets
